# %%
from global_.orchestrator_graph import Global_Orchestrator

# %%
from global_.state import Orchestrator_Global_State

# %%
from MAFI.agent_factory.graph_factory_concurrent import SubgraphFactory
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from MAFI.agent_factory.graph_factory_concurrent import SubgraphFactory
#
# File ~/Desktop/MAF/MAFI/agent_factory/graph_factory_concurrent.py:3
#       1 from typing import Any, Dict, List, Optional,Type
#       2 import json
# ----> 3 from langgraph import StateGraph,START, END
#       4 from langgraph.prebuilt import ToolNode
#       5 from config.config import get_shared_llm
#
# ImportError: cannot import name 'StateGraph' from 'langgraph' (unknown location)

# %%
orc = Global_Orchestrator(
    auto_load_skills=True,
    db_path="subgraph_registry.db",
    SubgraphFactory=Sub
)
